# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Import the random module.
import random
from citipy import citipy
## Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime
from scipy.stats import linregress
import gmaps
import requests
# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random Lats and Longis combo.
lat = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-90.000, high=90.000, size=2000)
lat_lngs = zip(lat, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 732

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        current_description = city_weather["weather"][0]["description"]       
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                         "Current Description": current_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bredasdorp
# Processing Record 2 of Set 1 | coihaique
# Processing Record 3 of Set 1 | sao gabriel da cachoeira
# Processing Record 4 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 5 of Set 1 | caernarfon
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | georgetown
# Processing Record 8 of Set 1 | hermanus
# Processing Record 9 of Set 1 | havre-saint-pierre
# Processing Record 10 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 11 of Set 1 | bambous virieux
# Processing Record 12 of Set 1 | cape town
# Processing Record 13 of Set 1 | mahebourg
# Processing Record 14 of Set 1 | port elizabeth
# Processing Record 15 of Set 1 | iqaluit
# Processing Record 16 of Set 1 | rio gallegos
# Processing Record 17 of Set 1 | mecca
# Processing Record 18 of Set 1 | atar
# Processing Record 19 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 20 of Set 1 | sabla
# Processing Record 21 of Set 1 | jamestown
# Processing Record 22 of Set 1 | port alfred
# Processing Record 23 of Set 1 | windhoek
# Processing Record 24 of Set 1 | ponta do sol
# Processing Record 25 of Set 1 | manicore
# Processing Record 26 of Set 1 | mar del plata
# Processing Record 27 of Set 1 | adrar
# Processing Record 28 of Set 1 | tuggurt
# City not found. Skipping...
# Processing Record 29 of Set 1 | lebu
# Processing Record 30 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 31 of Set 1 | caravelas
# Processing Record 32 of Set 1 | kruisfontein
# Processing Record 33 of Set 1 | coroata
# Processing Record 34 of Set 1 | busselton
# Processing Record 35 of Set 1 | bayir
# Processing Record 36 of Set 1 | nizwa
# Processing Record 37 of Set 1 | cabedelo
# Processing Record 38 of Set 1 | omboue
# Processing Record 39 of Set 1 | vardo
# Processing Record 40 of Set 1 | saint george
# Processing Record 41 of Set 1 | qaqortoq
# Processing Record 42 of Set 1 | falmouth
# Processing Record 43 of Set 1 | vila velha
# Processing Record 44 of Set 1 | harper
# Processing Record 45 of Set 1 | piacabucu
# Processing Record 46 of Set 1 | klaksvik
# Processing Record 47 of Set 1 | la ferte-bernard
# Processing Record 48 of Set 1 | zarasai
# Processing Record 49 of Set 1 | longyearbyen
# Processing Record 50 of Set 1 | victoria
# Processing Record 1 of Set 2 | lubben
# Processing Record 2 of Set 2 | chirongui
# Processing Record 3 of Set 2 | virginia beach
# Processing Record 4 of Set 2 | faya
# Processing Record 5 of Set 2 | mathbaria
# Processing Record 6 of Set 2 | ribeira grande
# Processing Record 7 of Set 2 | smithville
# Processing Record 8 of Set 2 | tasiilaq
# Processing Record 9 of Set 2 | narsaq
# Processing Record 10 of Set 2 | paracuru
# Processing Record 11 of Set 2 | qasigiannguit
# Processing Record 12 of Set 2 | saint-pierre
# Processing Record 13 of Set 2 | taltal
# Processing Record 14 of Set 2 | cayenne
# Processing Record 15 of Set 2 | upernavik
# Processing Record 16 of Set 2 | brigantine
# Processing Record 17 of Set 2 | grand-santi
# Processing Record 18 of Set 2 | matiguas
# Processing Record 19 of Set 2 | hamilton
# Processing Record 20 of Set 2 | mykolayivka
# Processing Record 21 of Set 2 | banda aceh
# Processing Record 22 of Set 2 | groningen
# Processing Record 23 of Set 2 | sao filipe
# Processing Record 24 of Set 2 | saldanha
# Processing Record 25 of Set 2 | galle
# Processing Record 26 of Set 2 | sao jose da coroa grande
# Processing Record 27 of Set 2 | punta arenas
# Processing Record 28 of Set 2 | carutapera
# Processing Record 29 of Set 2 | doha
# Processing Record 30 of Set 2 | luderitz
# Processing Record 31 of Set 2 | margate
# Processing Record 32 of Set 2 | east london
# Processing Record 33 of Set 2 | kalangala
# Processing Record 34 of Set 2 | matagami
# Processing Record 35 of Set 2 | khambhaliya
# Processing Record 36 of Set 2 | bandarbeyla
# Processing Record 37 of Set 2 | bocholt
# Processing Record 38 of Set 2 | sakakah
# Processing Record 39 of Set 2 | tabou
# Processing Record 40 of Set 2 | grindavik
# Processing Record 41 of Set 2 | tsabong
# Processing Record 42 of Set 2 | sept-iles
# Processing Record 43 of Set 2 | dieppe
# Processing Record 44 of Set 2 | novyy urengoy
# Processing Record 45 of Set 2 | karauzyak
# City not found. Skipping...
# Processing Record 46 of Set 2 | comodoro rivadavia
# Processing Record 47 of Set 2 | newry
# Processing Record 48 of Set 2 | san carlos de bariloche
# Processing Record 49 of Set 2 | aktash
# Processing Record 50 of Set 2 | viedma
# Processing Record 1 of Set 3 | bardiyah
# Processing Record 2 of Set 3 | vagur
# Processing Record 3 of Set 3 | svetlogorsk
# Processing Record 4 of Set 3 | kyabe
# Processing Record 5 of Set 3 | chuy
# Processing Record 6 of Set 3 | tengushevo
# Processing Record 7 of Set 3 | paradwip
# City not found. Skipping...
# Processing Record 8 of Set 3 | nizhnyaya pavlovka
# City not found. Skipping...
# Processing Record 9 of Set 3 | laranjeiras do sul
# Processing Record 10 of Set 3 | bilma
# Processing Record 11 of Set 3 | ambilobe
# Processing Record 12 of Set 3 | lagoa
# Processing Record 13 of Set 3 | gavle
# Processing Record 14 of Set 3 | husavik
# Processing Record 15 of Set 3 | requena
# Processing Record 16 of Set 3 | olafsvik
# Processing Record 17 of Set 3 | kavaratti
# Processing Record 18 of Set 3 | clyde river
# Processing Record 19 of Set 3 | abu zabad
# Processing Record 20 of Set 3 | vila franca do campo
# Processing Record 21 of Set 3 | nanortalik
# Processing Record 22 of Set 3 | nola
# Processing Record 23 of Set 3 | dingle
# Processing Record 24 of Set 3 | biltine
# Processing Record 25 of Set 3 | rio grande
# Processing Record 26 of Set 3 | qaanaaq
# Processing Record 27 of Set 3 | sidmouth
# Processing Record 28 of Set 3 | sao joao da barra
# Processing Record 29 of Set 3 | grand gaube
# Processing Record 30 of Set 3 | tazovskiy
# Processing Record 31 of Set 3 | bathsheba
# Processing Record 32 of Set 3 | namibe
# Processing Record 33 of Set 3 | surgut
# Processing Record 34 of Set 3 | burica
# City not found. Skipping...
# Processing Record 35 of Set 3 | japaratuba
# Processing Record 36 of Set 3 | loknya
# Processing Record 37 of Set 3 | alberton
# Processing Record 38 of Set 3 | sao borja
# Processing Record 39 of Set 3 | nouadhibou
# Processing Record 40 of Set 3 | dwarka
# Processing Record 41 of Set 3 | vangaindrano
# Processing Record 42 of Set 3 | rio cuarto
# Processing Record 43 of Set 3 | fort pierce
# Processing Record 44 of Set 3 | rio branco
# Processing Record 45 of Set 3 | mrirt
# City not found. Skipping...
# Processing Record 46 of Set 3 | wahran
# City not found. Skipping...
# Processing Record 47 of Set 3 | santa luzia
# Processing Record 48 of Set 3 | amalapuram
# Processing Record 49 of Set 3 | ibipeba
# Processing Record 50 of Set 3 | bokspits
# City not found. Skipping...
# Processing Record 1 of Set 4 | dikson
# Processing Record 2 of Set 4 | vestmannaeyjar
# Processing Record 3 of Set 4 | jega
# Processing Record 4 of Set 4 | pastavy
# Processing Record 5 of Set 4 | sangmelima
# Processing Record 6 of Set 4 | platanos
# Processing Record 7 of Set 4 | ostrovnoy
# Processing Record 8 of Set 4 | upata
# Processing Record 9 of Set 4 | millinocket
# Processing Record 10 of Set 4 | lake city
# Processing Record 11 of Set 4 | hambantota
# Processing Record 12 of Set 4 | zabol
# Processing Record 13 of Set 4 | orebro
# Processing Record 14 of Set 4 | saint-georges
# Processing Record 15 of Set 4 | cidreira
# Processing Record 16 of Set 4 | barreirinhas
# Processing Record 17 of Set 4 | piney green
# Processing Record 18 of Set 4 | marystown
# Processing Record 19 of Set 4 | uige
# Processing Record 20 of Set 4 | jasper
# Processing Record 21 of Set 4 | urucara
# Processing Record 22 of Set 4 | ilulissat
# Processing Record 23 of Set 4 | matara
# Processing Record 24 of Set 4 | araouane
# Processing Record 25 of Set 4 | arraial do cabo
# Processing Record 26 of Set 4 | hithadhoo
# Processing Record 27 of Set 4 | dugda
# Processing Record 28 of Set 4 | vestmanna
# Processing Record 29 of Set 4 | palaikastron
# Processing Record 30 of Set 4 | trairi
# Processing Record 31 of Set 4 | marsa matruh
# Processing Record 32 of Set 4 | scarborough
# Processing Record 33 of Set 4 | la palma
# Processing Record 34 of Set 4 | umm ruwabah
# City not found. Skipping...
# Processing Record 35 of Set 4 | atyrau
# Processing Record 36 of Set 4 | belomorsk
# Processing Record 37 of Set 4 | tarko-sale
# Processing Record 38 of Set 4 | zlatibor
# Processing Record 39 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 40 of Set 4 | itapecerica
# Processing Record 41 of Set 4 | morant bay
# Processing Record 42 of Set 4 | honningsvag
# Processing Record 43 of Set 4 | coquimbo
# Processing Record 44 of Set 4 | saint-philippe
# Processing Record 45 of Set 4 | banikoara
# Processing Record 46 of Set 4 | oruro
# Processing Record 47 of Set 4 | saint-francois
# Processing Record 48 of Set 4 | parrita
# Processing Record 49 of Set 4 | nampula
# Processing Record 50 of Set 4 | ambodifototra
# City not found. Skipping...
# Processing Record 1 of Set 5 | paamiut
# Processing Record 2 of Set 5 | mizdah
# Processing Record 3 of Set 5 | qeshm
# Processing Record 4 of Set 5 | eyl
# Processing Record 5 of Set 5 | iquitos
# Processing Record 6 of Set 5 | chicama
# Processing Record 7 of Set 5 | richmond
# Processing Record 8 of Set 5 | vilhena
# Processing Record 9 of Set 5 | xuddur
# Processing Record 10 of Set 5 | sena madureira
# Processing Record 11 of Set 5 | camacha
# Processing Record 12 of Set 5 | algiers
# Processing Record 13 of Set 5 | hammerfest
# Processing Record 14 of Set 5 | mehamn
# Processing Record 15 of Set 5 | kouango
# Processing Record 16 of Set 5 | krasne
# Processing Record 17 of Set 5 | merke
# Processing Record 18 of Set 5 | kalach-na-donu
# Processing Record 19 of Set 5 | jalu
# Processing Record 20 of Set 5 | mgandu
# Processing Record 21 of Set 5 | moa
# Processing Record 22 of Set 5 | tombouctou
# Processing Record 23 of Set 5 | souillac
# Processing Record 24 of Set 5 | lethem
# Processing Record 25 of Set 5 | liniere
# City not found. Skipping...
# Processing Record 26 of Set 5 | itambe
# Processing Record 27 of Set 5 | sinnamary
# Processing Record 28 of Set 5 | vallenar
# Processing Record 29 of Set 5 | baghdad
# Processing Record 30 of Set 5 | saint-augustin
# Processing Record 31 of Set 5 | colombo
# Processing Record 32 of Set 5 | south elgin
# Processing Record 33 of Set 5 | gamba
# Processing Record 34 of Set 5 | murmashi
# Processing Record 35 of Set 5 | farsund
# Processing Record 36 of Set 5 | naryan-mar
# Processing Record 37 of Set 5 | san pedro
# Processing Record 38 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 39 of Set 5 | sancti spiritus
# Processing Record 40 of Set 5 | ghanzi
# Processing Record 41 of Set 5 | torbay
# Processing Record 42 of Set 5 | izhma
# Processing Record 43 of Set 5 | moba
# Processing Record 44 of Set 5 | newton abbot
# Processing Record 45 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 46 of Set 5 | kattivakkam
# Processing Record 47 of Set 5 | asfi
# Processing Record 48 of Set 5 | hofn
# Processing Record 49 of Set 5 | barawe
# City not found. Skipping...
# Processing Record 50 of Set 5 | salalah
# Processing Record 1 of Set 6 | touros
# Processing Record 2 of Set 6 | takhatpur
# Processing Record 3 of Set 6 | suez
# Processing Record 4 of Set 6 | strezhevoy
# Processing Record 5 of Set 6 | olinda
# Processing Record 6 of Set 6 | dawlatabad
# Processing Record 7 of Set 6 | sherbakul
# Processing Record 8 of Set 6 | pangnirtung
# Processing Record 9 of Set 6 | amancio
# City not found. Skipping...
# Processing Record 10 of Set 6 | los llanos de aridane
# Processing Record 11 of Set 6 | cortland
# Processing Record 12 of Set 6 | saint anthony
# Processing Record 13 of Set 6 | kondinskoye
# Processing Record 14 of Set 6 | yangambi
# Processing Record 15 of Set 6 | ostrogozhsk
# Processing Record 16 of Set 6 | huarmey
# Processing Record 17 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 6 | yelan
# Processing Record 19 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 20 of Set 6 | abu dhabi
# Processing Record 21 of Set 6 | bucovat
# Processing Record 22 of Set 6 | gwadar
# Processing Record 23 of Set 6 | kralendijk
# Processing Record 24 of Set 6 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 25 of Set 6 | matcha
# Processing Record 26 of Set 6 | aguimes
# Processing Record 27 of Set 6 | baranain
# Processing Record 28 of Set 6 | barahona
# Processing Record 29 of Set 6 | gubkinskiy
# Processing Record 30 of Set 6 | bonfim
# Processing Record 31 of Set 6 | mizan teferi
# Processing Record 32 of Set 6 | riachao das neves
# Processing Record 33 of Set 6 | codrington
# Processing Record 34 of Set 6 | noyakert
# Processing Record 35 of Set 6 | umm lajj
# Processing Record 36 of Set 6 | caucaia
# Processing Record 37 of Set 6 | mazamari
# Processing Record 38 of Set 6 | cravo norte
# Processing Record 39 of Set 6 | basavakalyan
# Processing Record 40 of Set 6 | porosozero
# Processing Record 41 of Set 6 | ardakan
# Processing Record 42 of Set 6 | saint-joseph
# Processing Record 43 of Set 6 | male
# Processing Record 44 of Set 6 | puerto madryn
# Processing Record 45 of Set 6 | umm kaddadah
# Processing Record 46 of Set 6 | port-gentil
# Processing Record 47 of Set 6 | laguna
# Processing Record 48 of Set 6 | marfino
# Processing Record 49 of Set 6 | arys
# Processing Record 50 of Set 6 | bengkulu
# Processing Record 1 of Set 7 | uruguaiana
# Processing Record 2 of Set 7 | skagastrond
# City not found. Skipping...
# Processing Record 3 of Set 7 | garissa
# Processing Record 4 of Set 7 | pavlodar
# Processing Record 5 of Set 7 | kangaatsiaq
# Processing Record 6 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 7 of Set 7 | casablanca
# Processing Record 8 of Set 7 | quatre cocos
# Processing Record 9 of Set 7 | nouakchott
# Processing Record 10 of Set 7 | kitui
# Processing Record 11 of Set 7 | hatfield
# Processing Record 12 of Set 7 | saint-michel-des-saints
# Processing Record 13 of Set 7 | north chicago
# Processing Record 14 of Set 7 | ekibastuz
# Processing Record 15 of Set 7 | diego de almagro
# Processing Record 16 of Set 7 | mayahi
# Processing Record 17 of Set 7 | jonkoping
# Processing Record 18 of Set 7 | jauja
# Processing Record 19 of Set 7 | bojnurd
# Processing Record 20 of Set 7 | manjacaze
# Processing Record 21 of Set 7 | zuenoula
# Processing Record 22 of Set 7 | hualmay
# Processing Record 23 of Set 7 | kozan
# Processing Record 24 of Set 7 | necochea
# Processing Record 25 of Set 7 | kuusamo
# Processing Record 26 of Set 7 | bonavista
# Processing Record 27 of Set 7 | port blair
# Processing Record 28 of Set 7 | birjand
# Processing Record 29 of Set 7 | goundam
# Processing Record 30 of Set 7 | henties bay
# Processing Record 31 of Set 7 | kozhva
# Processing Record 32 of Set 7 | kachikau
# City not found. Skipping...
# Processing Record 33 of Set 7 | licata
# Processing Record 34 of Set 7 | grenville
# Processing Record 35 of Set 7 | pariquera-acu
# City not found. Skipping...
# Processing Record 36 of Set 7 | upington
# Processing Record 37 of Set 7 | krasnomayskiy
# Processing Record 38 of Set 7 | aksu
# Processing Record 39 of Set 7 | sao domingos
# Processing Record 40 of Set 7 | rio claro
# Processing Record 41 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 42 of Set 7 | aragarcas
# Processing Record 43 of Set 7 | richard toll
# City not found. Skipping...
# Processing Record 44 of Set 7 | ancud
# Processing Record 45 of Set 7 | marawi
# Processing Record 46 of Set 7 | carnarvon
# Processing Record 47 of Set 7 | usevya
# Processing Record 48 of Set 7 | mattru
# Processing Record 49 of Set 7 | roald
# Processing Record 50 of Set 7 | conde
# Processing Record 1 of Set 8 | aksay
# Processing Record 2 of Set 8 | geraldton
# Processing Record 3 of Set 8 | nebyliv
# Processing Record 4 of Set 8 | barranca
# Processing Record 5 of Set 8 | cap malheureux
# Processing Record 6 of Set 8 | ati
# Processing Record 7 of Set 8 | diplo
# Processing Record 8 of Set 8 | itaquyry
# Processing Record 9 of Set 8 | maracaibo
# Processing Record 10 of Set 8 | grafenhainichen
# Processing Record 11 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 12 of Set 8 | tawnat
# City not found. Skipping...
# Processing Record 13 of Set 8 | dennery
# Processing Record 14 of Set 8 | sao raimundo das mangabeiras
# Processing Record 15 of Set 8 | the valley
# Processing Record 16 of Set 8 | jamsa
# Processing Record 17 of Set 8 | sambava
# Processing Record 18 of Set 8 | richards bay
# Processing Record 19 of Set 8 | arlit
# Processing Record 20 of Set 8 | jardim
# Processing Record 21 of Set 8 | el angel
# Processing Record 22 of Set 8 | pangoa
# Processing Record 23 of Set 8 | turukhansk
# Processing Record 24 of Set 8 | acarau
# Processing Record 25 of Set 8 | bonthe
# Processing Record 26 of Set 8 | puerto colombia
# Processing Record 27 of Set 8 | goma
# Processing Record 28 of Set 8 | saladoblanco
# Processing Record 29 of Set 8 | iralaya
# Processing Record 30 of Set 8 | la tuque
# Processing Record 31 of Set 8 | cap-aux-meules
# Processing Record 32 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 33 of Set 8 | patacamaya
# Processing Record 34 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 35 of Set 8 | goderich
# Processing Record 36 of Set 8 | zhezkazgan
# Processing Record 37 of Set 8 | antofagasta
# Processing Record 38 of Set 8 | jumla
# Processing Record 39 of Set 8 | shar
# Processing Record 40 of Set 8 | mazagao
# Processing Record 41 of Set 8 | porto seguro
# Processing Record 42 of Set 8 | biala podlaska
# Processing Record 43 of Set 8 | dudinka
# Processing Record 44 of Set 8 | inhambane
# Processing Record 45 of Set 8 | plover
# Processing Record 46 of Set 8 | tucuman
# Processing Record 47 of Set 8 | srem
# Processing Record 48 of Set 8 | kumluca
# Processing Record 49 of Set 8 | lukovetskiy
# Processing Record 50 of Set 8 | itarema
# Processing Record 1 of Set 9 | dabakala
# Processing Record 2 of Set 9 | belmonte
# Processing Record 3 of Set 9 | columbus
# Processing Record 4 of Set 9 | soyo
# Processing Record 5 of Set 9 | basmat
# Processing Record 6 of Set 9 | marmande
# Processing Record 7 of Set 9 | hartford
# Processing Record 8 of Set 9 | bereda
# Processing Record 9 of Set 9 | mutsamudu
# City not found. Skipping...
# Processing Record 10 of Set 9 | verkhnetulomskiy
# Processing Record 11 of Set 9 | bartica
# Processing Record 12 of Set 9 | lerwick
# Processing Record 13 of Set 9 | sorland
# Processing Record 14 of Set 9 | wajir
# Processing Record 15 of Set 9 | savannah bight
# Processing Record 16 of Set 9 | logansport
# Processing Record 17 of Set 9 | trincomalee
# Processing Record 18 of Set 9 | kadiri
# Processing Record 19 of Set 9 | andenes
# Processing Record 20 of Set 9 | cutervo
# Processing Record 21 of Set 9 | behbahan
# Processing Record 22 of Set 9 | plettenberg bay
# Processing Record 23 of Set 9 | mwene-ditu
# Processing Record 24 of Set 9 | shelburne
# Processing Record 25 of Set 9 | lyngseidet
# Processing Record 26 of Set 9 | tessalit
# Processing Record 27 of Set 9 | bombay
# Processing Record 28 of Set 9 | amapa
# Processing Record 29 of Set 9 | hobyo
# Processing Record 30 of Set 9 | kristiinankaupunki
# Processing Record 31 of Set 9 | mingaora
# Processing Record 32 of Set 9 | shirochanka
# Processing Record 33 of Set 9 | waw
# Processing Record 34 of Set 9 | tubruq
# City not found. Skipping...
# Processing Record 35 of Set 9 | bhanpuri
# Processing Record 36 of Set 9 | laives
# Processing Record 37 of Set 9 | ciechocinek
# Processing Record 38 of Set 9 | gualeguay
# Processing Record 39 of Set 9 | marquette
# Processing Record 40 of Set 9 | fasa
# Processing Record 41 of Set 9 | ginda
# Processing Record 42 of Set 9 | sault sainte marie
# Processing Record 43 of Set 9 | cockburn town
# Processing Record 44 of Set 9 | villa vazquez
# City not found. Skipping...
# Processing Record 45 of Set 9 | pafos
# Processing Record 46 of Set 9 | praia
# Processing Record 47 of Set 9 | ludvika
# Processing Record 48 of Set 9 | camana
# Processing Record 49 of Set 9 | bam
# Processing Record 50 of Set 9 | kidal
# Processing Record 1 of Set 10 | yar-sale
# Processing Record 2 of Set 10 | chancay
# Processing Record 3 of Set 10 | calamar
# Processing Record 4 of Set 10 | siniscola
# Processing Record 5 of Set 10 | larsnes
# Processing Record 6 of Set 10 | boende
# Processing Record 7 of Set 10 | sur
# Processing Record 8 of Set 10 | tonj
# Processing Record 9 of Set 10 | havoysund
# Processing Record 10 of Set 10 | veselynove
# Processing Record 11 of Set 10 | marsh harbour
# Processing Record 12 of Set 10 | kivsharivka
# Processing Record 13 of Set 10 | lima
# Processing Record 14 of Set 10 | thompson
# Processing Record 15 of Set 10 | sabaudia
# Processing Record 16 of Set 10 | libreville
# Processing Record 17 of Set 10 | salamiyah
# Processing Record 18 of Set 10 | izazi
# Processing Record 19 of Set 10 | caucasia
# Processing Record 20 of Set 10 | sao felix do xingu
# Processing Record 21 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 22 of Set 10 | sar-e pul
# Processing Record 23 of Set 10 | neftegorsk
# Processing Record 24 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 25 of Set 10 | leshukonskoye
# Processing Record 26 of Set 10 | dmitriyev-lgovskiy
# City not found. Skipping...
# Processing Record 27 of Set 10 | ajtos
# Processing Record 28 of Set 10 | mariental
# Processing Record 29 of Set 10 | cururupu
# Processing Record 30 of Set 10 | ust-kulom
# Processing Record 31 of Set 10 | valparaiso
# Processing Record 32 of Set 10 | hakkari
# Processing Record 33 of Set 10 | dera ghazi khan
# Processing Record 34 of Set 10 | nebolchi
# Processing Record 35 of Set 10 | nuuk
# Processing Record 36 of Set 10 | portsmouth
# Processing Record 37 of Set 10 | rocha
# Processing Record 38 of Set 10 | borshchiv
# Processing Record 39 of Set 10 | mezen
# Processing Record 40 of Set 10 | sinop
# Processing Record 41 of Set 10 | pesochenskiy
# Processing Record 42 of Set 10 | mian channun
# Processing Record 43 of Set 10 | tapaua
# City not found. Skipping...
# Processing Record 44 of Set 10 | inza
# Processing Record 45 of Set 10 | brae
# Processing Record 46 of Set 10 | mayumba
# Processing Record 47 of Set 10 | dzhusaly
# City not found. Skipping...
# Processing Record 48 of Set 10 | adre
# Processing Record 49 of Set 10 | harrismith
# Processing Record 50 of Set 10 | pachino
# Processing Record 1 of Set 11 | gurupi
# Processing Record 2 of Set 11 | kabalo
# Processing Record 3 of Set 11 | bako
# Processing Record 4 of Set 11 | pozo colorado
# Processing Record 5 of Set 11 | kinkala
# Processing Record 6 of Set 11 | tabira
# Processing Record 7 of Set 11 | muzhi
# Processing Record 8 of Set 11 | nalut
# Processing Record 9 of Set 11 | vigrestad
# Processing Record 10 of Set 11 | constitucion
# Processing Record 11 of Set 11 | manacor
# Processing Record 12 of Set 11 | iskilip
# Processing Record 13 of Set 11 | korem
# Processing Record 14 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 15 of Set 11 | sochi
# Processing Record 16 of Set 11 | lincoln
# Processing Record 17 of Set 11 | san luis
# Processing Record 18 of Set 11 | nikolskoye
# Processing Record 19 of Set 11 | dalvik
# Processing Record 20 of Set 11 | inirida
# Processing Record 21 of Set 11 | umm durman
# City not found. Skipping...
# Processing Record 22 of Set 11 | ouadda
# Processing Record 23 of Set 11 | machali
# Processing Record 24 of Set 11 | wittlich
# Processing Record 25 of Set 11 | labrea
# Processing Record 26 of Set 11 | khandbari
# Processing Record 27 of Set 11 | union city
# Processing Record 28 of Set 11 | inta
# Processing Record 29 of Set 11 | sistranda
# Processing Record 30 of Set 11 | pisco
# Processing Record 31 of Set 11 | baijiantan
# Processing Record 32 of Set 11 | estelle
# Processing Record 33 of Set 11 | sydney mines
# Processing Record 34 of Set 11 | kamenka
# Processing Record 35 of Set 11 | pesochnoye
# Processing Record 36 of Set 11 | barra dos coqueiros
# Processing Record 37 of Set 11 | mantua
# Processing Record 38 of Set 11 | tall kayf
# Processing Record 39 of Set 11 | santo tomas
# Processing Record 40 of Set 11 | malmyzh
# Processing Record 41 of Set 11 | riohacha
# Processing Record 42 of Set 11 | nienburg
# Processing Record 43 of Set 11 | taoudenni
# Processing Record 44 of Set 11 | jamame
# Processing Record 45 of Set 11 | san andres
# Processing Record 46 of Set 11 | menongue
# Processing Record 47 of Set 11 | sal rei
# Processing Record 48 of Set 11 | troitsko-pechorsk
# Processing Record 49 of Set 11 | ciudad guayana
# Processing Record 50 of Set 11 | mangrol
# Processing Record 1 of Set 12 | bad kissingen
# Processing Record 2 of Set 12 | guapore
# Processing Record 3 of Set 12 | labytnangi
# Processing Record 4 of Set 12 | cholet
# Processing Record 5 of Set 12 | lambarene
# Processing Record 6 of Set 12 | sesheke
# Processing Record 7 of Set 12 | parfenyevo
# Processing Record 8 of Set 12 | valmiera
# Processing Record 9 of Set 12 | karkaralinsk
# City not found. Skipping...
# Processing Record 10 of Set 12 | suluq
# Processing Record 11 of Set 12 | port-de-paix
# City not found. Skipping...
# Processing Record 12 of Set 12 | santa ines
# Processing Record 13 of Set 12 | hit
# Processing Record 14 of Set 12 | muravlenko
# Processing Record 15 of Set 12 | santiago del estero
# Processing Record 16 of Set 12 | urumqi
# Processing Record 17 of Set 12 | mudgal
# Processing Record 18 of Set 12 | puyo
# Processing Record 19 of Set 12 | san juan de los morros
# Processing Record 20 of Set 12 | chavantes
# Processing Record 21 of Set 12 | maniitsoq
# Processing Record 22 of Set 12 | krasnoborsk
# Processing Record 23 of Set 12 | mayor pablo lagerenza
# Processing Record 24 of Set 12 | gazli
# Processing Record 25 of Set 12 | synya
# Processing Record 26 of Set 12 | astana
# Processing Record 27 of Set 12 | oktyabrskiy
# Processing Record 28 of Set 12 | mutis
# Processing Record 29 of Set 12 | uvinza
# Processing Record 30 of Set 12 | verkhnyaya pyshma
# Processing Record 31 of Set 12 | oum hadjer
# Processing Record 32 of Set 12 | mpongwe
# Processing Record 33 of Set 12 | cozumel
# Processing Record 34 of Set 12 | maloshuyka
# City not found. Skipping...
# Processing Record 35 of Set 12 | bubaque
# Processing Record 36 of Set 12 | beypur
# City not found. Skipping...
# Processing Record 37 of Set 12 | kondopoga
# Processing Record 38 of Set 12 | gat
# Processing Record 39 of Set 12 | muros
# Processing Record 40 of Set 12 | nadym
# Processing Record 41 of Set 12 | azangaro
# Processing Record 42 of Set 12 | farafangana
# Processing Record 43 of Set 12 | yara
# Processing Record 44 of Set 12 | diffa
# Processing Record 45 of Set 12 | conceicao do araguaia
# Processing Record 46 of Set 12 | oranjestad
# Processing Record 47 of Set 12 | kiruna
# Processing Record 48 of Set 12 | polunochnoye
# Processing Record 49 of Set 12 | uchkent
# Processing Record 50 of Set 12 | hunza
# City not found. Skipping...
# Processing Record 1 of Set 13 | elizabeth city
# Processing Record 2 of Set 13 | lundazi
# Processing Record 3 of Set 13 | rafai
# Processing Record 4 of Set 13 | diapaga
# Processing Record 5 of Set 13 | sol-iletsk
# Processing Record 6 of Set 13 | rundu
# Processing Record 7 of Set 13 | csavoly
# Processing Record 8 of Set 13 | killybegs
# Processing Record 9 of Set 13 | canutama
# Processing Record 10 of Set 13 | jork
# Processing Record 11 of Set 13 | cascas
# Processing Record 12 of Set 13 | marrakesh
# Processing Record 13 of Set 13 | kedrovyy
# Processing Record 14 of Set 13 | karpogory
# Processing Record 15 of Set 13 | seydisehir
# Processing Record 16 of Set 13 | juybar
# Processing Record 17 of Set 13 | kirovohrad
# Processing Record 18 of Set 13 | santa helena
# Processing Record 19 of Set 13 | polovinnoye
# Processing Record 20 of Set 13 | hornepayne
# Processing Record 21 of Set 13 | natal
# Processing Record 22 of Set 13 | kismayo
# Processing Record 23 of Set 13 | gulshat
# City not found. Skipping...
# Processing Record 24 of Set 13 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 25 of Set 13 | mahibadhoo
# Processing Record 26 of Set 13 | matay
# Processing Record 27 of Set 13 | sao joao do piaui
# Processing Record 28 of Set 13 | kintinku
# Processing Record 29 of Set 13 | bichena
# Processing Record 30 of Set 13 | ornskoldsvik
# Processing Record 31 of Set 13 | kurchum
# Processing Record 32 of Set 13 | oeiras
# Processing Record 33 of Set 13 | halifax
# Processing Record 34 of Set 13 | soledade
# Processing Record 35 of Set 13 | ascension
# Processing Record 36 of Set 13 | ippy
# Processing Record 37 of Set 13 | clarence town
# Processing Record 38 of Set 13 | manaus
# Processing Record 39 of Set 13 | melk
# Processing Record 40 of Set 13 | lahan
# Processing Record 41 of Set 13 | noyabrsk
# Processing Record 42 of Set 13 | chikitigarh
# Processing Record 43 of Set 13 | challapata
# Processing Record 44 of Set 13 | ahwa
# Processing Record 45 of Set 13 | mandera
# Processing Record 46 of Set 13 | shache
# Processing Record 47 of Set 13 | nakskov
# Processing Record 48 of Set 13 | oranjemund
# Processing Record 49 of Set 13 | belyy yar
# Processing Record 50 of Set 13 | maltahohe
# Processing Record 1 of Set 14 | valdivia
# Processing Record 2 of Set 14 | watsa
# Processing Record 3 of Set 14 | barbar
# City not found. Skipping...
# Processing Record 4 of Set 14 | athieme
# City not found. Skipping...
# Processing Record 5 of Set 14 | iracoubo
# Processing Record 6 of Set 14 | chitipa
# Processing Record 7 of Set 14 | macherla
# Processing Record 8 of Set 14 | bani
# Processing Record 9 of Set 14 | kuryk
# Processing Record 10 of Set 14 | carbondale
# Processing Record 11 of Set 14 | linden
# Processing Record 12 of Set 14 | julio de castilhos
# Processing Record 13 of Set 14 | la primavera
# Processing Record 14 of Set 14 | ngama
# Processing Record 15 of Set 14 | jibuti
# Processing Record 16 of Set 14 | castro
# Processing Record 17 of Set 14 | korla
# Processing Record 18 of Set 14 | lekoni
# Processing Record 19 of Set 14 | barcelos
# Processing Record 20 of Set 14 | hvide sande
# Processing Record 21 of Set 14 | zirl
# Processing Record 22 of Set 14 | puri
# Processing Record 23 of Set 14 | sompeta
# Processing Record 24 of Set 14 | meulaboh
# Processing Record 25 of Set 14 | peniche
# Processing Record 26 of Set 14 | argalasti
# Processing Record 27 of Set 14 | oistins
# Processing Record 28 of Set 14 | najran
# Processing Record 29 of Set 14 | obera
# Processing Record 30 of Set 14 | betioky
# Processing Record 31 of Set 14 | barkly west
# Processing Record 32 of Set 14 | gerash
# Processing Record 33 of Set 14 | chapais
# Processing Record 34 of Set 14 | vetapalem
# Processing Record 35 of Set 14 | pontecorvo
# Processing Record 36 of Set 14 | malumfashi
# Processing Record 37 of Set 14 | ponta delgada
# Processing Record 38 of Set 14 | temir
# Processing Record 39 of Set 14 | kumbo
# Processing Record 40 of Set 14 | saint-ambroise
# Processing Record 41 of Set 14 | dhidhdhoo
# Processing Record 42 of Set 14 | rawson
# Processing Record 43 of Set 14 | shibarghan
# City not found. Skipping...
# Processing Record 44 of Set 14 | kirkwall
# Processing Record 45 of Set 14 | ercis
# Processing Record 46 of Set 14 | usinsk
# Processing Record 47 of Set 14 | gao
# Processing Record 48 of Set 14 | englewood
# Processing Record 49 of Set 14 | khorixas
# Processing Record 50 of Set 14 | darab
# Processing Record 1 of Set 15 | chongwe
# Processing Record 2 of Set 15 | rio formoso
# Processing Record 3 of Set 15 | zlitan
# Processing Record 4 of Set 15 | togur
# Processing Record 5 of Set 15 | khanna
# Processing Record 6 of Set 15 | lasa
# Processing Record 7 of Set 15 | tres arroyos
# Processing Record 8 of Set 15 | kutum
# Processing Record 9 of Set 15 | seguela
# Processing Record 10 of Set 15 | chingola
# Processing Record 11 of Set 15 | tchollire
# Processing Record 12 of Set 15 | nowy targ
# Processing Record 13 of Set 15 | san-pedro
# Processing Record 14 of Set 15 | san cristobal
# Processing Record 15 of Set 15 | dakar
# Processing Record 16 of Set 15 | zhanaozen
# Processing Record 17 of Set 15 | paita
# Processing Record 18 of Set 15 | marzuq
# Processing Record 19 of Set 15 | kemlya
# Processing Record 20 of Set 15 | olenino
# Processing Record 21 of Set 15 | olavarria
# Processing Record 22 of Set 15 | paytug
# City not found. Skipping...
# Processing Record 23 of Set 15 | buenos aires
# Processing Record 24 of Set 15 | nohar
# Processing Record 25 of Set 15 | galgani
# City not found. Skipping...
# Processing Record 26 of Set 15 | kaputa
# Processing Record 27 of Set 15 | taft
# Processing Record 28 of Set 15 | granada
# Processing Record 29 of Set 15 | scottsburgh
# City not found. Skipping...
# Processing Record 30 of Set 15 | perelyub
# Processing Record 31 of Set 15 | harnosand
# Processing Record 32 of Set 15 | pamplona
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 676

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                        City Country      Lat       Lng  Max Temp  Humidity  \
# 0                Bredasdorp      ZA -34.5322   20.0403     72.28        83
# 1                 Coihaique      CL -45.5752  -72.0662     48.81        71
# 2  Sao Gabriel Da Cachoeira      BR  -0.1303  -67.0892     74.03        94
# 3                Caernarfon      GB  53.1413   -4.2702     45.52        70
# 4                   Ushuaia      AR -54.8000  -68.3000     44.26        70
# 5                Georgetown      MY   5.4112  100.3354     89.53        64
# 6                  Hermanus      ZA -34.4187   19.2345     72.81        79
# 7        Havre-Saint-Pierre      CA  50.2334  -63.5986     12.20        66
# 8           Bambous Virieux      MU -20.3428   57.7575     84.22        89
# 9                 Cape Town      ZA -33.9258   18.4232     70.21        78
#
#    Cloudiness  Wind Speed Current Description
# 0         100        8.05     overcast clouds
# 1          40        2.30    scattered clouds
# 2          97        1.77     overcast clouds
# 3          75       24.16       broken clouds
# 4          40        8.05    scattered clouds
# 5          20        4.61          few clouds
# 6         100       12.50     overcast clouds
# 7         100       12.66     overcast clouds
# 8          75       12.66          light rain
# 9           0        1.99           clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file)
